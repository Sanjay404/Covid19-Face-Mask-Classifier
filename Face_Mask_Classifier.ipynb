# %% [markdown]
# #Covid19 Face Mask Classifier
#
#
# *   Classifies images of people based on whether or not they are wearing a face mask.

# %% [markdown]
# ### Mounting Google Drive/Importing Data

# %%
from google.colab import drive
drive.mount('/content/drive')
root_dir = "/content/drive/My Drive/"
base_dir = root_dir + 'Colab Notebooks/tmp'
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %% [markdown]
# ###Imports tensorflow

# %%
import tensorflow as tf

# %% [markdown]
# ### Creating the Model
# Add the densely connected layers for *binary classification*
#
# *   Uses Santa/Not Santa Classification Model

# %%
# import the necessary packages
from keras.models import Sequential
from keras.layers.convolutional import Conv2D
from keras.layers.convolutional import MaxPooling2D
from keras.layers.core import Activation
from keras.layers.core import Flatten
from keras.layers.core import Dense
from keras import backend as K
class LeNet:
	@staticmethod
	def build(width, height, depth, classes):
		# initialize the model
		model = Sequential()
		inputShape = (height, width, depth)
		# if we are using "channels first", update the input shape
		if K.image_data_format() == "channels_first":
			inputShape = (depth, height, width)
	 
	 # first set of CONV => RELU => POOL layers
		model.add(Conv2D(20, (5, 5), padding="same",
			input_shape=inputShape))
		model.add(Activation("relu"))
		model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
	# second set of CONV => RELU => POOL layers
		model.add(Conv2D(50, (5, 5), padding="same"))
		model.add(Activation("relu"))
		model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
	# first (and only) set of FC => RELU layers
		model.add(Flatten())
		model.add(Dense(500))
		model.add(Activation("relu"))
		# softmax classifier
		model.add(Dense(classes))
		model.add(Activation("softmax"))
		# return the constructed network architecture
		return model

# %%
# set the matplotlib backend so figures can be saved in the background
import matplotlib
matplotlib.use("Agg")
# import the necessary packages
from keras.preprocessing.image import ImageDataGenerator
from keras.optimizers import Adam
from sklearn.model_selection import train_test_split
from keras.preprocessing.image import img_to_array
from keras.utils import to_categorical
#from pyimagesearch.lenet import LeNet
from imutils import paths
import matplotlib.pyplot as plt
import numpy as np
import argparse
import random
import cv2
import os

# initialize the number of epochs to train for, initial learning rate,
# and batch size
EPOCHS = 150 #optimal number of epochs for classification
INIT_LR = 1e-3
BS = 32 #CHANGE
# Dictionary containting path to dataset in mounted google drive
args = {
 "dataset": base_dir ,
 "model": "model.h5",
 "plot" :"plot.png"
}
print("[INFO] loading images...")
data = []
labels = []
# grab the image paths and randomly shuffle them
imagePaths = sorted(list(paths.list_images(args["dataset"])))
random.seed(42)
random.shuffle(imagePaths)
# loop over the input images
for imagePath in imagePaths:
	# load the image, pre-process it, and store it in the data list
	image = cv2.imread(imagePath)
	image = cv2.resize(image, (28, 28))
	image = img_to_array(image)
	data.append(image)
	# extract the class label from the image path and update the
	# labels list
	label = imagePath.split(os.path.sep)[-2]
	label = 1 if label == "mask" else 0
	labels.append(label)
 # scale the raw pixel intensities to the range [0, 1]
data = np.array(data, dtype="float") / 255.0
labels = np.array(labels)
# partition the data into training and testing splits using 75% of
# the data for training and the remaining 25% for testing
(trainX, testX, trainY, testY) = train_test_split(data,
	labels, test_size=0.25, random_state=42)
# convert the labels from integers to vectors
trainY = to_categorical(trainY, num_classes=2)
testY = to_categorical(testY, num_classes=2)
# construct the image generator for data augmentation
aug = ImageDataGenerator(rotation_range=30, width_shift_range=0.1,
	height_shift_range=0.1, shear_range=0.2, zoom_range=0.2,
	horizontal_flip=True, fill_mode="nearest")
# initialize the model
print("[INFO] compiling model...")
model = LeNet.build(width=28, height=28, depth=3, classes=2)
opt = Adam(lr=INIT_LR, decay=INIT_LR / EPOCHS)
model.compile(loss="binary_crossentropy", optimizer=opt,
	metrics=["accuracy"])
# train the network
print("[INFO] training network...")
H = model.fit_generator(aug.flow(trainX, trainY, batch_size=BS),
	validation_data=(testX, testY), steps_per_epoch=len(trainX) // BS,
	epochs=EPOCHS, verbose=1)
# save the model to disk
print("[INFO] serializing network...")
model.save(args["model"])
# plot the training loss and accuracy
plt.style.use("ggplot")
plt.figure()
N = EPOCHS
plt.plot(np.arange(0, N), H.history["loss"], label="train_loss")
plt.plot(np.arange(0, N), H.history["val_loss"], label="val_loss")
plt.plot(np.arange(0, N), H.history["accuracy"], label="train_acc")
plt.plot(np.arange(0, N), H.history["val_accuracy"], label="val_acc")
plt.title("Training Loss and Accuracy on Mask/No Mask")
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend(loc="lower left")
plt.savefig(args["plot"])
# Out:
# [INFO] loading images...
# [INFO] compiling model...
# [INFO] training network...
# Epoch 1/150
# 58/58 [==============================] - 1s 19ms/step - loss: 0.5619 - accuracy: 0.7077 - val_loss: 0.4385 - val_accuracy: 0.7961
# Epoch 2/150
# 58/58 [==============================] - 1s 19ms/step - loss: 0.4124 - accuracy: 0.8135 - val_loss: 0.3864 - val_accuracy: 0.8507
# Epoch 3/150
# 58/58 [==============================] - 1s 19ms/step - loss: 0.3626 - accuracy: 0.8370 - val_loss: 0.3192 - val_accuracy: 0.8828
# Epoch 4/150
# 58/58 [==============================] - 1s 19ms/step - loss: 0.3399 - accuracy: 0.8582 - val_loss: 0.3621 - val_accuracy: 0.8636
# Epoch 5/150
# 58/58 [==============================] - 1s 19ms/step - loss: 0.3201 - accuracy: 0.8708 - val_loss: 0.3182 - val_accuracy: 0.8844
# Epoch 6/150
# 58/58 [==============================] - 1s 18ms/step - loss: 0.2965 - accuracy: 0.8768 - val_loss: 0.3088 - val_accuracy: 0.8828
# Epoch 7/150
# 58/58 [==============================] - 1s 19ms/step - loss: 0.2896 - accuracy: 0.8915 - val_loss: 0.3156 - val_accuracy: 0.8844
# Epoch 8/150
# 58/58 [==============================] - 1s 19ms/step - loss: 0.2903 - accuracy: 0.8811 - val_loss: 0.3425 - val_accuracy: 0.8604
# Epoch 9/150
# 58/58 [==============================] - 1s 18ms/step - loss: 0.2840 - accuracy: 0.8844 - val_loss: 0.3123 - val_accuracy: 0.8748
# Epoch 10/150
# 58/58 [==============================] - 1s 19ms/step - loss: 0.2688 - accuracy: 0.8955 - val_loss: 0.2785 - val_accuracy: 0.8909
# Epoch 11/150
# 58/58 [==============================] - 1s 19ms/step - loss: 0.2562 - accuracy: 0.9024 - val_loss: 0.2771 - val_accuracy: 0.8989
# Epoch 12/150
# 58/58 [==============================] - 1s 18ms/step - loss: 0.2459 - accuracy: 0.9029 - val_loss: 0.2986 - val_accuracy: 0.8909
# Epoch 13/150
# 58/58 [==============================] - 1s 18ms/step - loss: 0.2509 - accuracy: 0.8980 - val_loss: 0.3351 - val_accuracy: 0.8828
# Epoch 14/150
# 58/58 [==============================] - 1s 18ms/step - loss: 0.2098 - accuracy: 0.9171 - val_loss: 0.3165 - val_accuracy: 0.8909
# Epoch 15/150
# 58/58 [==============================] - 1s 18ms/step - loss: 0.2304 - accuracy: 0.9138 - val_loss: 0.2406 - val_accuracy: 0.9262
# Epoch 16/150
# 58/58 [==============================] - 1s 18ms/step - loss: 0.2040 - accuracy: 0.9182 - val_loss: 0.2528 - val_accuracy: 0.9165
# Epoch 17/150
# 58/58 [==============================] - 1s 20ms/step - loss: 0.2054 - accuracy: 0.9222 - val_loss: 0.2578 - val_accuracy: 0.9133
# Epoch 18/150
# 58/58 [==============================] - 1s 18ms/step - loss: 0.2257 - accuracy: 0.9073 - val_loss: 0.2854 - val_accuracy: 0.9101
# Epoch 19/150
# 58/58 [==============================] - 1s 19ms/step - loss: 0.2336 - accuracy: 0.9134 - val_loss: 0.3063 - val_accuracy: 0.9133
# Epoch 20/150
# 58/58 [==============================] - 1s 17ms/step - loss: 0.2208 - accuracy: 0.9117 - val_loss: 0.3228 - val_accuracy: 0.8925
# Epoch 21/150
# 58/58 [==============================] - 1s 18ms/step - loss: 0.1792 - accuracy: 0.9297 - val_loss: 0.2652 - val_accuracy: 0.9117
# Epoch 22/150
# 58/58 [==============================] - 1s 18ms/step - loss: 0.1952 - accuracy: 0.9258 - val_loss: 0.2455 - val_accuracy: 0.9149
# Epoch 23/150
# 58/58 [==============================] - 1s 18ms/step - loss: 0.1684 - accuracy: 0.9348 - val_loss: 0.2296 - val_accuracy: 0.9197
# Epoch 24/150
# 58/58 [==============================] - 1s 18ms/step - loss: 0.1970 - accuracy: 0.9198 - val_loss: 0.2689 - val_accuracy: 0.9085
# Epoch 25/150
# 58/58 [==============================] - 1s 18ms/step - loss: 0.1579 - accuracy: 0.9404 - val_loss: 0.2135 - val_accuracy: 0.9262
# Epoch 26/150
# 58/58 [==============================] - 1s 18ms/step - loss: 0.1743 - accuracy: 0.9291 - val_loss: 0.2257 - val_accuracy: 0.9310
# Epoch 27/150
# 58/58 [==============================] - 1s 18ms/step - loss: 0.1528 - accuracy: 0.9449 - val_loss: 0.2176 - val_accuracy: 0.9262
# Epoch 28/150
# 58/58 [==============================] - 1s 18ms/step - loss: 0.1580 - accuracy: 0.9417 - val_loss: 0.2645 - val_accuracy: 0.9294
# Epoch 29/150
# 58/58 [==============================] - 1s 17ms/step - loss: 0.1579 - accuracy: 0.9364 - val_loss: 0.2143 - val_accuracy: 0.9342
# Epoch 30/150
# 58/58 [==============================] - 1s 18ms/step - loss: 0.1729 - accuracy: 0.9324 - val_loss: 0.2321 - val_accuracy: 0.9246
# Epoch 31/150
# 58/58 [==============================] - 1s 18ms/step - loss: 0.1559 - accuracy: 0.9360 - val_loss: 0.2779 - val_accuracy: 0.9165
# Epoch 32/150
# 58/58 [==============================] - 1s 18ms/step - loss: 0.1345 - accuracy: 0.9444 - val_loss: 0.2862 - val_accuracy: 0.9278
# Epoch 33/150
# 58/58 [==============================] - 1s 18ms/step - loss: 0.1536 - accuracy: 0.9380 - val_loss: 0.2327 - val_accuracy: 0.9342
# Epoch 34/150
# 58/58 [==============================] - 1s 18ms/step - loss: 0.1421 - accuracy: 0.9422 - val_loss: 0.2721 - val_accuracy: 0.9053
# Epoch 35/150
# 58/58 [==============================] - 1s 18ms/step - loss: 0.1602 - accuracy: 0.9332 - val_loss: 0.2108 - val_accuracy: 0.9358
# Epoch 36/150
# 58/58 [==============================] - 1s 18ms/step - loss: 0.1350 - accuracy: 0.9526 - val_loss: 0.2428 - val_accuracy: 0.9294
# Epoch 37/150
# 58/58 [==============================] - 1s 18ms/step - loss: 0.1401 - accuracy: 0.9466 - val_loss: 0.2362 - val_accuracy: 0.9390
# Epoch 38/150
# 58/58 [==============================] - 1s 18ms/step - loss: 0.1346 - accuracy: 0.9510 - val_loss: 0.2744 - val_accuracy: 0.9165
# Epoch 39/150
# 58/58 [==============================] - 1s 18ms/step - loss: 0.1542 - accuracy: 0.9404 - val_loss: 0.2260 - val_accuracy: 0.9278
# Epoch 40/150
# 58/58 [==============================] - 1s 18ms/step - loss: 0.1209 - accuracy: 0.9574 - val_loss: 0.3503 - val_accuracy: 0.9117
# Epoch 41/150
# 58/58 [==============================] - 1s 18ms/step - loss: 0.1458 - accuracy: 0.9376 - val_loss: 0.2272 - val_accuracy: 0.9246
# Epoch 42/150
# 58/58 [==============================] - 1s 18ms/step - loss: 0.1038 - accuracy: 0.9597 - val_loss: 0.2915 - val_accuracy: 0.9069
# Epoch 43/150
# 58/58 [==============================] - 1s 18ms/step - loss: 0.1388 - accuracy: 0.9483 - val_loss: 0.2443 - val_accuracy: 0.9390
# Epoch 44/150
# 58/58 [==============================] - 1s 20ms/step - loss: 0.1316 - accuracy: 0.9503 - val_loss: 0.2375 - val_accuracy: 0.9406
# Epoch 45/150
# 58/58 [==============================] - 1s 17ms/step - loss: 0.1155 - accuracy: 0.9542 - val_loss: 0.2753 - val_accuracy: 0.9310
# Epoch 46/150
# 58/58 [==============================] - 1s 18ms/step - loss: 0.1095 - accuracy: 0.9575 - val_loss: 0.2586 - val_accuracy: 0.9342
# Epoch 47/150
# 58/58 [==============================] - 1s 18ms/step - loss: 0.1326 - accuracy: 0.9465 - val_loss: 0.2657 - val_accuracy: 0.9390
# Epoch 48/150
# 58/58 [==============================] - 1s 18ms/step - loss: 0.1307 - accuracy: 0.9467 - val_loss: 0.2074 - val_accuracy: 0.9422
# Epoch 49/150
# 58/58 [==============================] - 1s 18ms/step - loss: 0.1240 - accuracy: 0.9509 - val_loss: 0.2136 - val_accuracy: 0.9374
# Epoch 50/150
# 58/58 [==============================] - 1s 18ms/step - loss: 0.1105 - accuracy: 0.9613 - val_loss: 0.2627 - val_accuracy: 0.9310
# Epoch 51/150
# 58/58 [==============================] - 1s 18ms/step - loss: 0.0940 - accuracy: 0.9613 - val_loss: 0.2593 - val_accuracy: 0.9358
# Epoch 52/150
# 58/58 [==============================] - 1s 17ms/step - loss: 0.1194 - accuracy: 0.9537 - val_loss: 0.2604 - val_accuracy: 0.9374
# Epoch 53/150
# 58/58 [==============================] - 1s 18ms/step - loss: 0.1238 - accuracy: 0.9537 - val_loss: 0.2254 - val_accuracy: 0.9390
# Epoch 54/150
# 58/58 [==============================] - 1s 18ms/step - loss: 0.1128 - accuracy: 0.9553 - val_loss: 0.2639 - val_accuracy: 0.9342
# Epoch 55/150
# 58/58 [==============================] - 1s 17ms/step - loss: 0.0973 - accuracy: 0.9646 - val_loss: 0.3019 - val_accuracy: 0.9358
# Epoch 56/150
# 58/58 [==============================] - 1s 17ms/step - loss: 0.1065 - accuracy: 0.9602 - val_loss: 0.2299 - val_accuracy: 0.9422
# Epoch 57/150
# 58/58 [==============================] - 1s 18ms/step - loss: 0.0931 - accuracy: 0.9651 - val_loss: 0.2132 - val_accuracy: 0.9502
# Epoch 58/150
# 58/58 [==============================] - 1s 18ms/step - loss: 0.0935 - accuracy: 0.9607 - val_loss: 0.2115 - val_accuracy: 0.9518
# Epoch 59/150
# 58/58 [==============================] - 1s 17ms/step - loss: 0.1084 - accuracy: 0.9580 - val_loss: 0.2231 - val_accuracy: 0.9342
# Epoch 60/150
# 58/58 [==============================] - 1s 17ms/step - loss: 0.1123 - accuracy: 0.9629 - val_loss: 0.2494 - val_accuracy: 0.9406
# Epoch 61/150
# 58/58 [==============================] - 1s 20ms/step - loss: 0.1078 - accuracy: 0.9597 - val_loss: 0.2491 - val_accuracy: 0.9470
# Epoch 62/150
# 58/58 [==============================] - 1s 18ms/step - loss: 0.0866 - accuracy: 0.9640 - val_loss: 0.2490 - val_accuracy: 0.9406
# Epoch 63/150
# 58/58 [==============================] - 1s 19ms/step - loss: 0.1000 - accuracy: 0.9635 - val_loss: 0.2587 - val_accuracy: 0.9374
# Epoch 64/150
# 58/58 [==============================] - 1s 19ms/step - loss: 0.0776 - accuracy: 0.9695 - val_loss: 0.2344 - val_accuracy: 0.9422
# Epoch 65/150
# 58/58 [==============================] - 1s 21ms/step - loss: 0.0911 - accuracy: 0.9640 - val_loss: 0.2429 - val_accuracy: 0.9390
# Epoch 66/150
# 58/58 [==============================] - 1s 17ms/step - loss: 0.0964 - accuracy: 0.9617 - val_loss: 0.2835 - val_accuracy: 0.9342
# Epoch 67/150
# 58/58 [==============================] - 1s 19ms/step - loss: 0.0922 - accuracy: 0.9674 - val_loss: 0.2255 - val_accuracy: 0.9502
# Epoch 68/150
# 58/58 [==============================] - 1s 19ms/step - loss: 0.0923 - accuracy: 0.9656 - val_loss: 0.2340 - val_accuracy: 0.9454
# Epoch 69/150
# 58/58 [==============================] - 1s 19ms/step - loss: 0.0892 - accuracy: 0.9656 - val_loss: 0.2086 - val_accuracy: 0.9454
# Epoch 70/150
# 58/58 [==============================] - 1s 19ms/step - loss: 0.1122 - accuracy: 0.9580 - val_loss: 0.2026 - val_accuracy: 0.9486
# Epoch 71/150
# 58/58 [==============================] - 1s 19ms/step - loss: 0.0808 - accuracy: 0.9673 - val_loss: 0.2437 - val_accuracy: 0.9470
# Epoch 72/150
# 58/58 [==============================] - 1s 19ms/step - loss: 0.0985 - accuracy: 0.9624 - val_loss: 0.2124 - val_accuracy: 0.9422
# Epoch 73/150
# 58/58 [==============================] - 1s 18ms/step - loss: 0.0786 - accuracy: 0.9733 - val_loss: 0.2501 - val_accuracy: 0.9470
# Epoch 74/150
# 58/58 [==============================] - 1s 18ms/step - loss: 0.0875 - accuracy: 0.9689 - val_loss: 0.2241 - val_accuracy: 0.9502
# Epoch 75/150
# 58/58 [==============================] - 1s 18ms/step - loss: 0.0745 - accuracy: 0.9678 - val_loss: 0.2471 - val_accuracy: 0.9535
# Epoch 76/150
# 58/58 [==============================] - 1s 18ms/step - loss: 0.0685 - accuracy: 0.9760 - val_loss: 0.2361 - val_accuracy: 0.9406
# Epoch 77/150
# 58/58 [==============================] - 1s 18ms/step - loss: 0.0598 - accuracy: 0.9809 - val_loss: 0.2621 - val_accuracy: 0.9518
# Epoch 78/150
# 58/58 [==============================] - 1s 18ms/step - loss: 0.0676 - accuracy: 0.9731 - val_loss: 0.2883 - val_accuracy: 0.9422
# Epoch 79/150
# 58/58 [==============================] - 1s 18ms/step - loss: 0.0812 - accuracy: 0.9741 - val_loss: 0.2592 - val_accuracy: 0.9422
# Epoch 80/150
# 58/58 [==============================] - 1s 18ms/step - loss: 0.0769 - accuracy: 0.9684 - val_loss: 0.2103 - val_accuracy: 0.9551
# Epoch 81/150
# 58/58 [==============================] - 1s 18ms/step - loss: 0.1037 - accuracy: 0.9618 - val_loss: 0.3113 - val_accuracy: 0.9374
# Epoch 82/150
# 58/58 [==============================] - 1s 18ms/step - loss: 0.0714 - accuracy: 0.9744 - val_loss: 0.2778 - val_accuracy: 0.9374
# Epoch 83/150
# 58/58 [==============================] - 1s 18ms/step - loss: 0.0746 - accuracy: 0.9741 - val_loss: 0.3069 - val_accuracy: 0.9342
# Epoch 84/150
# 58/58 [==============================] - 1s 19ms/step - loss: 0.0991 - accuracy: 0.9629 - val_loss: 0.2857 - val_accuracy: 0.9438
# Epoch 85/150
# 58/58 [==============================] - 1s 18ms/step - loss: 0.0809 - accuracy: 0.9680 - val_loss: 0.2395 - val_accuracy: 0.9454
# Epoch 86/150
# 58/58 [==============================] - 1s 18ms/step - loss: 0.0743 - accuracy: 0.9725 - val_loss: 0.3164 - val_accuracy: 0.9374
# Epoch 87/150
# 58/58 [==============================] - 1s 18ms/step - loss: 0.0817 - accuracy: 0.9695 - val_loss: 0.2519 - val_accuracy: 0.9406
# Epoch 88/150
# 58/58 [==============================] - 1s 18ms/step - loss: 0.0627 - accuracy: 0.9719 - val_loss: 0.2157 - val_accuracy: 0.9470
# Epoch 89/150
# 58/58 [==============================] - 1s 18ms/step - loss: 0.0529 - accuracy: 0.9817 - val_loss: 0.3611 - val_accuracy: 0.9278
# Epoch 90/150
# 58/58 [==============================] - 1s 18ms/step - loss: 0.0672 - accuracy: 0.9735 - val_loss: 0.2970 - val_accuracy: 0.9310
# Epoch 91/150
# 58/58 [==============================] - 1s 18ms/step - loss: 0.0780 - accuracy: 0.9736 - val_loss: 0.2592 - val_accuracy: 0.9294
# Epoch 92/150
# 58/58 [==============================] - 1s 18ms/step - loss: 0.1123 - accuracy: 0.9592 - val_loss: 0.2788 - val_accuracy: 0.9278
# Epoch 93/150
# 58/58 [==============================] - 1s 18ms/step - loss: 0.0800 - accuracy: 0.9720 - val_loss: 0.2870 - val_accuracy: 0.9406
# Epoch 94/150
# 58/58 [==============================] - 1s 18ms/step - loss: 0.0792 - accuracy: 0.9640 - val_loss: 0.2464 - val_accuracy: 0.9438
# Epoch 95/150
# 58/58 [==============================] - 1s 18ms/step - loss: 0.0733 - accuracy: 0.9708 - val_loss: 0.2449 - val_accuracy: 0.9422
# Epoch 96/150
# 58/58 [==============================] - 1s 18ms/step - loss: 0.0926 - accuracy: 0.9624 - val_loss: 0.2624 - val_accuracy: 0.9438
# Epoch 97/150
# 58/58 [==============================] - 1s 18ms/step - loss: 0.0677 - accuracy: 0.9741 - val_loss: 0.2633 - val_accuracy: 0.9486
# Epoch 98/150
# 58/58 [==============================] - 1s 18ms/step - loss: 0.0486 - accuracy: 0.9820 - val_loss: 0.2933 - val_accuracy: 0.9438
# Epoch 99/150
# 58/58 [==============================] - 1s 18ms/step - loss: 0.0639 - accuracy: 0.9706 - val_loss: 0.2241 - val_accuracy: 0.9551
# Epoch 100/150
# 58/58 [==============================] - 1s 18ms/step - loss: 0.0555 - accuracy: 0.9771 - val_loss: 0.2781 - val_accuracy: 0.9438
# Epoch 101/150
# 58/58 [==============================] - 1s 18ms/step - loss: 0.0503 - accuracy: 0.9785 - val_loss: 0.2688 - val_accuracy: 0.9470
# Epoch 102/150
# 58/58 [==============================] - 1s 18ms/step - loss: 0.0708 - accuracy: 0.9747 - val_loss: 0.2889 - val_accuracy: 0.9342
# Epoch 103/150
# 58/58 [==============================] - 1s 18ms/step - loss: 0.0549 - accuracy: 0.9815 - val_loss: 0.2976 - val_accuracy: 0.9438
# Epoch 104/150
# 58/58 [==============================] - 1s 17ms/step - loss: 0.0619 - accuracy: 0.9798 - val_loss: 0.2779 - val_accuracy: 0.9358
# Epoch 105/150
# 58/58 [==============================] - 1s 18ms/step - loss: 0.0740 - accuracy: 0.9685 - val_loss: 0.2213 - val_accuracy: 0.9502
# Epoch 106/150
# 58/58 [==============================] - 1s 18ms/step - loss: 0.0620 - accuracy: 0.9747 - val_loss: 0.2768 - val_accuracy: 0.9374
# Epoch 107/150
# 58/58 [==============================] - 1s 18ms/step - loss: 0.0509 - accuracy: 0.9809 - val_loss: 0.2869 - val_accuracy: 0.9438
# Epoch 108/150
# 58/58 [==============================] - 1s 18ms/step - loss: 0.0877 - accuracy: 0.9691 - val_loss: 0.2717 - val_accuracy: 0.9390
# Epoch 109/150
# 58/58 [==============================] - 1s 18ms/step - loss: 0.0550 - accuracy: 0.9774 - val_loss: 0.2723 - val_accuracy: 0.9518
# Epoch 110/150
# 58/58 [==============================] - 1s 17ms/step - loss: 0.0713 - accuracy: 0.9760 - val_loss: 0.2645 - val_accuracy: 0.9518
# Epoch 111/150
# 58/58 [==============================] - 1s 18ms/step - loss: 0.0435 - accuracy: 0.9851 - val_loss: 0.2319 - val_accuracy: 0.9535
# Epoch 112/150
# 58/58 [==============================] - 1s 18ms/step - loss: 0.0650 - accuracy: 0.9784 - val_loss: 0.2401 - val_accuracy: 0.9390
# Epoch 113/150
# 58/58 [==============================] - 1s 18ms/step - loss: 0.0483 - accuracy: 0.9815 - val_loss: 0.2751 - val_accuracy: 0.9406
# Epoch 114/150
# 58/58 [==============================] - 1s 18ms/step - loss: 0.0589 - accuracy: 0.9790 - val_loss: 0.2706 - val_accuracy: 0.9358
# Epoch 115/150
# 58/58 [==============================] - 1s 18ms/step - loss: 0.0510 - accuracy: 0.9822 - val_loss: 0.2499 - val_accuracy: 0.9535
# Epoch 116/150
# 58/58 [==============================] - 1s 18ms/step - loss: 0.0546 - accuracy: 0.9809 - val_loss: 0.3078 - val_accuracy: 0.9374
# Epoch 117/150
# 58/58 [==============================] - 1s 18ms/step - loss: 0.0623 - accuracy: 0.9787 - val_loss: 0.2904 - val_accuracy: 0.9470
# Epoch 118/150
# 58/58 [==============================] - 1s 17ms/step - loss: 0.0390 - accuracy: 0.9864 - val_loss: 0.3535 - val_accuracy: 0.9438
# Epoch 119/150
# 58/58 [==============================] - 1s 17ms/step - loss: 0.0529 - accuracy: 0.9798 - val_loss: 0.2866 - val_accuracy: 0.9438
# Epoch 120/150
# 58/58 [==============================] - 1s 18ms/step - loss: 0.0432 - accuracy: 0.9826 - val_loss: 0.3063 - val_accuracy: 0.9454
# Epoch 121/150
# 58/58 [==============================] - 1s 19ms/step - loss: 0.0648 - accuracy: 0.9787 - val_loss: 0.2993 - val_accuracy: 0.9422
# Epoch 122/150
# 58/58 [==============================] - 1s 19ms/step - loss: 0.0727 - accuracy: 0.9760 - val_loss: 0.2915 - val_accuracy: 0.9438
# Epoch 123/150
# 58/58 [==============================] - 1s 19ms/step - loss: 0.0474 - accuracy: 0.9817 - val_loss: 0.2940 - val_accuracy: 0.9535
# Epoch 124/150
# 58/58 [==============================] - 1s 19ms/step - loss: 0.0587 - accuracy: 0.9801 - val_loss: 0.3071 - val_accuracy: 0.9470
# Epoch 125/150
# 58/58 [==============================] - 1s 18ms/step - loss: 0.0383 - accuracy: 0.9871 - val_loss: 0.3252 - val_accuracy: 0.9454
# Epoch 126/150
# 58/58 [==============================] - 1s 18ms/step - loss: 0.1026 - accuracy: 0.9635 - val_loss: 0.2778 - val_accuracy: 0.9422
# Epoch 127/150
# 58/58 [==============================] - 1s 18ms/step - loss: 0.0663 - accuracy: 0.9741 - val_loss: 0.3058 - val_accuracy: 0.9406
# Epoch 128/150
# 58/58 [==============================] - 1s 19ms/step - loss: 0.0506 - accuracy: 0.9820 - val_loss: 0.2798 - val_accuracy: 0.9454
# Epoch 129/150
# 58/58 [==============================] - 1s 19ms/step - loss: 0.0540 - accuracy: 0.9793 - val_loss: 0.2415 - val_accuracy: 0.9470
# Epoch 130/150
# 58/58 [==============================] - 1s 18ms/step - loss: 0.0378 - accuracy: 0.9847 - val_loss: 0.2410 - val_accuracy: 0.9535
# Epoch 131/150
# 58/58 [==============================] - 1s 18ms/step - loss: 0.0471 - accuracy: 0.9831 - val_loss: 0.3044 - val_accuracy: 0.9422
# Epoch 132/150
# 58/58 [==============================] - 1s 18ms/step - loss: 0.0438 - accuracy: 0.9817 - val_loss: 0.3054 - val_accuracy: 0.9438
# Epoch 133/150
# 58/58 [==============================] - 1s 17ms/step - loss: 0.0752 - accuracy: 0.9757 - val_loss: 0.2616 - val_accuracy: 0.9518
# Epoch 134/150
# 58/58 [==============================] - 1s 18ms/step - loss: 0.0550 - accuracy: 0.9820 - val_loss: 0.2749 - val_accuracy: 0.9406
# Epoch 135/150
# 58/58 [==============================] - 1s 20ms/step - loss: 0.0398 - accuracy: 0.9847 - val_loss: 0.2196 - val_accuracy: 0.9583
# Epoch 136/150
# 58/58 [==============================] - 1s 17ms/step - loss: 0.0387 - accuracy: 0.9869 - val_loss: 0.3046 - val_accuracy: 0.9518
# Epoch 137/150
# 58/58 [==============================] - 1s 18ms/step - loss: 0.0424 - accuracy: 0.9822 - val_loss: 0.3140 - val_accuracy: 0.9390
# Epoch 138/150
# 58/58 [==============================] - 1s 18ms/step - loss: 0.0506 - accuracy: 0.9829 - val_loss: 0.2958 - val_accuracy: 0.9438
# Epoch 139/150
# 58/58 [==============================] - 1s 18ms/step - loss: 0.0345 - accuracy: 0.9887 - val_loss: 0.2895 - val_accuracy: 0.9470
# Epoch 140/150
# 58/58 [==============================] - 1s 18ms/step - loss: 0.0269 - accuracy: 0.9880 - val_loss: 0.3340 - val_accuracy: 0.9374
# Epoch 141/150
# 58/58 [==============================] - 1s 18ms/step - loss: 0.0636 - accuracy: 0.9807 - val_loss: 0.3353 - val_accuracy: 0.9422
# Epoch 142/150
# 58/58 [==============================] - 1s 18ms/step - loss: 0.0605 - accuracy: 0.9784 - val_loss: 0.2639 - val_accuracy: 0.9470
# Epoch 143/150
# 58/58 [==============================] - 1s 18ms/step - loss: 0.0470 - accuracy: 0.9840 - val_loss: 0.2805 - val_accuracy: 0.9583
# Epoch 144/150
# 58/58 [==============================] - 1s 18ms/step - loss: 0.0325 - accuracy: 0.9914 - val_loss: 0.2801 - val_accuracy: 0.9502
# Epoch 145/150
# 58/58 [==============================] - 1s 18ms/step - loss: 0.0420 - accuracy: 0.9823 - val_loss: 0.3548 - val_accuracy: 0.9454
# Epoch 146/150
# 58/58 [==============================] - 1s 18ms/step - loss: 0.0455 - accuracy: 0.9844 - val_loss: 0.2923 - val_accuracy: 0.9502
# Epoch 147/150
# 58/58 [==============================] - 1s 18ms/step - loss: 0.0412 - accuracy: 0.9842 - val_loss: 0.3561 - val_accuracy: 0.9422
# Epoch 148/150
# 58/58 [==============================] - 1s 17ms/step - loss: 0.0514 - accuracy: 0.9834 - val_loss: 0.2814 - val_accuracy: 0.9390
# Epoch 149/150
# 58/58 [==============================] - 1s 18ms/step - loss: 0.0341 - accuracy: 0.9892 - val_loss: 0.2752 - val_accuracy: 0.9454
# Epoch 150/150
# 58/58 [==============================] - 1s 18ms/step - loss: 0.0386 - accuracy: 0.9857 - val_loss: 0.3143 - val_accuracy: 0.9454
# [INFO] serializing network...

# %% [markdown]
# ###Displays Saved Image

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline 
img= mpimg.imread('/content/plot.png')
imgplot = plt.imshow(img)
plt.show()
